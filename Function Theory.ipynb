# %% [raw]
# 1. What is the difference between a function and a method in Python?
#     Ans: Function: A function is a block of reusable code that is defined using the def keyword and can be called independently.
# Example:
# def greet():
#     return "Hello"
# print(greet())
#
# Method:A method is a function associated with an object or class, usually called using . notation.
# Example:
# text = "hello"
# print(text.upper())
#
# 2. Explain the concept of function arguments and parameters in Python.
#     Ans: Parameters are placeholders used when defining a function. Arguments are actual values passed when calling the function.
# Example:
# def greet(name):  # 'name' is a parameter
#     return "Hello " + name
#
# print(greet("Alice"))
#
# 3. What are the different ways to define and call a function in Python?
#     Ans: Define a function using def:
# Example:
# def add(a, b):
#     return a + b
# print(add(5, 3))
#
# -> Define an anonymous function using lambda:
# Example:
# add = lambda a, b: a + b
# print(add(5, 3))
#
# 4. What is the purpose of the `return` statement in a Python function?
#     Ans: The return statement sends back a value from a function to where it was called.
# Example:
# def square(x):
#     return x * x
#
# result = square(4)
# print(result)  # Output: 16
#
# 5. What are iterators in Python and how do they differ from iterables?
#     Ans: Iterable: An object capable of returning its elements one at a time (e.g., list, tuple, string).
# Iterator: An object with a state that remembers where it is during iteration. It implements the __next__() method.
#
# Example:
# numbers = [1, 2, 3]  # Iterable
# it = iter(numbers)   # Iterator
#
# print(next(it))  # Output: 1
# print(next(it))  # Output: 2
#
# 6. Explain the concept of generators in Python and how they are defined.
#     Ans: A generator is a function that yields values one at a time using the yield keyword. It remembers its state between calls.
# Example:
# def count_up_to(n):
#     count = 1
#     while count <= n:
#         yield count
#         count += 1
#
# for number in count_up_to(3):
#     print(number)
#
# 7. What are the advantages of using generators over regular functions?
#     Ans: Memory Efficient: Generates items one by one without storing the whole sequence in memory.
#          Lazy Evaluation: Useful for working with large datasets or streams.
# Example Difference:
#
# Regular function:
# def squares_list(n):
#     return [i * i for i in range(n)]
#
# Generator:
# def squares_gen(n):
#     for i in range(n):
#         yield i * i
#
# 8. What is a lambda function in Python and when is it typically used?
#     Ans: A lambda function is an anonymous (unnamed), single-expression function.
# Typical Uses:
#
# Short functions for map(), filter(), reduce(), etc.
#
#
# Example:
# lambda arguments: expression #Syntax
#
# square = lambda x: x * x
# print(square(5))  # Output: 25
#
# 9. Explain the purpose and usage of the `map()` function in Python.
#     Ans: map() applies a function to each item in an iterable.
# Example:
# numbers = [1, 2, 3, 4]
# squared = map(lambda x: x * x, numbers)
# print(list(squared))  # Output: [1, 4, 9, 16]
#
#
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#     Ans : | Function     | Purpose                                                | Example                                     |
# | ------------ | ------------------------------------------------------ | ------------------------------------------- |
# | **map()**    | Applies a function to each element                     | `map(lambda x: x+1, [1,2,3])` → \[2,3,4]    |
# | **filter()** | Filters elements based on condition                    | `filter(lambda x: x>2, [1,2,3,4])` → \[3,4] |
# | **reduce()** | Reduces sequence to a single value (needs `functools`) | `reduce(lambda x,y: x+y, [1,2,3,4])` → 10   |
#
#
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
#
#     Ans: List Given: [47, 11, 42, 13]
#
# #Code
#
# from functools import reduce
# numbers = [47, 11, 42, 13]
# result = reduce(lambda x, y: x + y, numbers)
# print(result)  # Output: 113
#
#
# | Step | x   | y  | Operation | Result |
# | ---- | --- | -- | --------- | ------ |
# | 1    | 47  | 11 | 47 + 11   | 58     |
# | 2    | 58  | 42 | 58 + 42   | 100    |
# | 3    | 100 | 13 | 100 + 13  | 113    |
